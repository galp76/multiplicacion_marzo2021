# %%
import time
import sumatoria


def formato(y):
    time.sleep(2)
    print('')
    print(a.rjust(15, ' ')+' * '+b)
    print(('-'*(long_a+long_b+3)).rjust((18+long_b)))
    for k in range(l+1):
        y=rstd[k]
        print(y.rjust(15-k, ' '))
    time.sleep(2)
    print('')
    print('Presiona ENTER para continuar')
    q=input()

def multiplicar(x, y):
    global llvm, f0, f1, resultado, l 
    for j in range(1, long_b+1):
        llvm=0
        resultado=''
        if l>0:
            rstd.append('')
        for i in range(1, long_a+1):
            c=int(x[long_a-i])*int(y[long_b-j])
            d=str(c)
            g=c+llvm 
            h=str(g)
            if len(d)==2:
                f1=h[1]
                f0=h[0]
            else:
                f1=h 
                f0='0'
            time.sleep(2)
            print('Cuanto es '+x[long_a-i]+' multiplicado por '+y[long_b-j]+'?')
            resp=input()
            time.sleep(2)
            while resp!=d:
                print('Respuesta incorrecta, por favor introduce el número correcto...')
                resp=input()
            if i==long_a:
                time.sleep(2)
                print('Correcto... y '+str(llvm)+' que llevamos son '+h+'\n\n')
                time.sleep(2)
                print('Como es el último número de la izquierda ponemos el '+h+' completo')
                resultado=f0+f1+resultado 
            else:
                print('\nCorrecto... y '+str(llvm)+' que llevamos son '+h+'\n\n')
                time.sleep(2)
                print('Ponemos el '+f1+' y llevamos '+f0)
                resultado=f1+resultado 
            rstd[l]=resultado 
            llvm=int(f0)
            formato(rstd[l])
        l=l+1

        

print('\nHola Germán, vamos a hacer multiplicaciones')
time.sleep(2)

print('\nPor favor introduce el primer número y presiona ENTER:') 
a=input()
long_a=len(a)
time.sleep(2)

print('\nAhora introduce el segundo número y presiona ENTER:')
b=input()
long_b=len(b)
time.sleep(2)

print('\nVamos a hacer la siguiente multiplicación:\n')
time.sleep(2)

print(a.rjust(15, ' ')+' * '+b)
print(('-'*(long_a+long_b+3)).rjust((18+long_b)))
time.sleep(2)

print('\nPresiona ENTER para continuar.')
q=input()
rstd=['']
llvm=0
f0=''
f1=''
l=0
resultado=''
smtr=['']
suma_total=0

multiplicar(a, b)

valor_corregido = ''
rstd_corregido = []

for i, item in enumerate(rstd):
    valor_corregido = item.lstrip('0')
    valor_corregido = valor_corregido + '0'*i
    rstd_corregido.append(valor_corregido)

print('Ahora tenemos que sumar para terminar con el ejercicio.')

sumatoria.a_sumar(rstd_corregido)
